# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import median_filter
from scipy.signal import find_peaks

def analyze_trace_and_relative_peaks(trace,
                                     window_size=10,
                                     smooth_size=14,
                                     threshold_percentile=85.45):
    trace = np.array(trace)
    n = len(trace)

    if window_size >= n:
        window_size_local = max(10, n // 10)
    else:
        window_size_local = window_size

    variance = np.array([
        np.var(trace[i:i + window_size_local])
        for i in range(n - window_size_local)
    ])
    variance = np.pad(variance, (0, window_size_local), mode='edge')

    vmin, vmax = np.min(variance), np.max(variance)
    if vmax > vmin:
        variance_norm = (variance - vmin) / (vmax - vmin)
    else:
        variance_norm = np.zeros_like(variance)

    if smooth_size < 1:
        smooth_size = 1
    if smooth_size % 2 == 0:
        smooth_size += 1

    variance_smooth = median_filter(variance_norm, size=smooth_size)

    threshold = np.percentile(variance_smooth, threshold_percentile)

    peak_indices, peak_props = find_peaks(variance_smooth, height=threshold)
    print(f"Found {len(peak_indices)} peaks in moving variance")

    peak_indices_rel = peak_indices.copy()
    for i in range(0, len(peak_indices_rel), 4):
        group = peak_indices_rel[i:i+4]
        if len(group) == 0:
            continue
        base = group[0]
        peak_indices_rel[i:i+4] = group - base

    plt.figure(figsize=(16, 12))

    ax1 = plt.subplot(3, 1, 1)
    ax1.plot(trace, linewidth=0.5)
    ax1.set_title(f'Power Trace (len={len(trace)})')
    ax1.set_ylabel('Power')
    ax1.grid(True, alpha=0.3)

    ax2 = plt.subplot(3, 1, 2)
    ax2.plot(variance_smooth, label='variance_smooth')
    ax2.axhline(y=threshold, color='r', linestyle='--',
                label=f'Threshold={threshold:.3f}')
    ax2.scatter(peak_indices, variance_smooth[peak_indices],
                color='magenta', marker='x', s=40, label='peaks')
    ax2.set_title('Moving Variance with Peaks (Full)')
    ax2.set_xlabel('Sample')
    ax2.set_ylabel('Variance')
    ax2.legend(fontsize=8)
    ax2.grid(True, alpha=0.3)

    ax3 = plt.subplot(3, 1, 3)
    zoom_end = min(4000, len(variance_smooth))
    zoom_mask = np.arange(zoom_end)

    ax3.plot(variance_smooth[:zoom_end], label='variance_smooth')

    ax3.axhline(y=threshold, color='r', linestyle='--',
                label=f'Threshold={threshold:.3f}')

    zoom_peaks = peak_indices[peak_indices < zoom_end]
    ax3.scatter(zoom_peaks, variance_smooth[zoom_peaks],
                color='magenta', marker='x', s=40, label='peaks')

    ax3.set_title('Moving Variance with Peaks (Zoomed: first 4000 samples)')
    ax3.set_xlabel('Sample')
    ax3.set_ylabel('Variance')
    ax3.legend(fontsize=8)
    ax3.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

    return peak_indices_rel

rel_peaks = analyze_trace_and_relative_peaks(np.load("middle_fingers_trace.npy"))
print("Relative peaks (grouped by 4):", rel_peaks)
# Out:
# Found 450 peaks in moving variance
# Relative peaks (grouped by 4): [  0  50 102 133   0  50  81 132   0  49  80 111   0  49  80 132   0  49
#  101 132   0  49  80 132   0  49  80 132   0  49 101 132   0  49 101 132
#    0  49  80 111   0  49 101 132   0  70 102 133   0  49 101 132   0  49
#   80 132   0  50 101 132   0  50 101 132   0  49 101 132   0  49  80 111
#    0  49  80 132   0  49  80 111   0  49 101 132   0  50  80 132   0  49
#  101 132   0  49  80 111   0  70 101 132   0  49  80 111   0  70 101 132
#    0  70 101 132   0  49 101 132   0  49 101 132   0  49  80 111   0  49
#   80 111   0  70 101 132   0  49  80 111   0  49 101 132   0  70 101 132
#    0  49 101 132   0  49  80 111   0  49 101 132   0  49 101 132   0  49
#  101 132   0  49  80 111   0  49 101 132   0  70 101 132   0  70 101 132
#    0  49  80 111   0  70 101 132   0  70 101 132   0  49 101 132   0  49
#   81 132   0  49  80 111   0  49 101 132   0  70 101 132   0  49  80 111
#    0  49 101 132   0  70 101 132   0  49 102 132   0  49  80 111   0  49
#  101 132   0  70 101 133   0  70 101 132   0  49  80 111   0  70 101 132
#    0  49  80 111   0  49 101 132   0  49 101 132   0  49  80 111   0  49
#   80 111   0  70 101 132   0  49  80 111   0  70 101 132   0  70 101 132
#    0  49 101 132   0  49  80 111   0  70 101 132   0  49  80 132   0  49
#  101 132   0  49 101 132   0  49  80 111   0  49  80 111   0  49 101 132
#    0  49  80 132   0  49 101 132   0  49  80 111   0  70 101 132   0  49
#   80 111   0  70 101 132   0  70 101 132   0  49 101 132   0  49 101 132
#    0  49  80 111   0  49  80 111   0  49 101 132   0  49  80 132   0  49
#   80 132   0  70 101 132   0  70 101 132   0  49  80 111   0  70 101 132
#    0  70 101 132   0  49 101 133   0  49  80 132   0  49  80 111   0  49
#  101 132   0  70 101 132   0  49  81 111   0  70 101 132   0  49  80 111
#    0  49 101 132   0  49  80 111   0  49  80 111   0  49 101 132   0 154]

# %%
def classify_groups(arr, error_margin_a=10, error_margin_bc=10):
    
    case_to_binary = {
        'A': '00',
        'B': '01',
        'C': '10',
        'D': '11'
    }
    results = []
    
    for i in range(0, len(arr), 4):
        group = arr[i:i+4]
        
        if len(group) != 4:
            print(f"Skipping incomplete group: {group}")
            continue
        
        e1, e2, e3, e4 = group
        
        diff_1_2 = abs(e2 - e1)
        diff_2_3 = abs(e3 - e2)
        diff_3_4 = abs(e4 - e3)
        
        case = 'D'
        
        if abs(diff_1_2 - 70) <= error_margin_a:
            case = 'A'
        elif abs(diff_2_3 - 50) <= error_margin_bc:
            case = 'B'
        elif abs(diff_3_4 - 50) <= error_margin_bc:
            case = 'C'
        
        results.append({
            'group': group,
            'case': case,
            'binary': case_to_binary[case],
            'diffs': {
                '1-2': diff_1_2,
                '2-3': diff_2_3,
                '3-4': diff_3_4
            }
        })
    
    binary_string = ''.join([r['binary'] for r in results])
    ascii_message = binary_to_ascii(binary_string)
    
    return results, binary_string, ascii_message


def binary_to_ascii(binary_string):
    ascii_chars = []
    
    for i in range(0, len(binary_string), 8):
        byte = binary_string[i:i+8]
        if len(byte) == 8:
            ascii_value = int(byte, 2)
            ascii_chars.append(chr(ascii_value))
    
    return ''.join(ascii_chars)

results, binary_string, ascii_message = classify_groups(rel_peaks)

print("Classification Results:")
print("=" * 60)
for idx, result in enumerate(results, 1):
    print(f"\nGroup {idx}: {result['group']}")
    print(f"  Case: {result['case']} → Binary: {result['binary']}")
    print(f"  Differences: 1-2={result['diffs']['1-2']}, "
          f"2-3={result['diffs']['2-3']}, 3-4={result['diffs']['3-4']}")

print("\n" + "=" * 60)
print(f"\nFull Binary String: {binary_string}")
print(f"Binary Length: {len(binary_string)} bits")
print(f"\nDecoded ASCII Message: '{ascii_message}'")
# Out:
# Skipping incomplete group: [  0 154]
# Classification Results:
# ============================================================
#
# Group 1: [  0  50 102 133]
#   Case: B → Binary: 01
#   Differences: 1-2=50, 2-3=52, 3-4=31
#
# Group 2: [  0  50  81 132]
#   Case: C → Binary: 10
#   Differences: 1-2=50, 2-3=31, 3-4=51
#
# Group 3: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 4: [  0  49  80 132]
#   Case: C → Binary: 10
#   Differences: 1-2=49, 2-3=31, 3-4=52
#
# Group 5: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 6: [  0  49  80 132]
#   Case: C → Binary: 10
#   Differences: 1-2=49, 2-3=31, 3-4=52
#
# Group 7: [  0  49  80 132]
#   Case: C → Binary: 10
#   Differences: 1-2=49, 2-3=31, 3-4=52
#
# Group 8: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 9: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 10: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 11: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 12: [  0  70 102 133]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=32, 3-4=31
#
# Group 13: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 14: [  0  49  80 132]
#   Case: C → Binary: 10
#   Differences: 1-2=49, 2-3=31, 3-4=52
#
# Group 15: [  0  50 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=50, 2-3=51, 3-4=31
#
# Group 16: [  0  50 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=50, 2-3=51, 3-4=31
#
# Group 17: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 18: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 19: [  0  49  80 132]
#   Case: C → Binary: 10
#   Differences: 1-2=49, 2-3=31, 3-4=52
#
# Group 20: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 21: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 22: [  0  50  80 132]
#   Case: C → Binary: 10
#   Differences: 1-2=50, 2-3=30, 3-4=52
#
# Group 23: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 24: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 25: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 26: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 27: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 28: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 29: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 30: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 31: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 32: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 33: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 34: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 35: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 36: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 37: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 38: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 39: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 40: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 41: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 42: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 43: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 44: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 45: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 46: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 47: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 48: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 49: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 50: [  0  49  81 132]
#   Case: C → Binary: 10
#   Differences: 1-2=49, 2-3=32, 3-4=51
#
# Group 51: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 52: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 53: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 54: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 55: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 56: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 57: [  0  49 102 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=53, 3-4=30
#
# Group 58: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 59: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 60: [  0  70 101 133]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=32
#
# Group 61: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 62: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 63: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 64: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 65: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 66: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 67: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 68: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 69: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 70: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 71: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 72: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 73: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 74: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 75: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 76: [  0  49  80 132]
#   Case: C → Binary: 10
#   Differences: 1-2=49, 2-3=31, 3-4=52
#
# Group 77: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 78: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 79: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 80: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 81: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 82: [  0  49  80 132]
#   Case: C → Binary: 10
#   Differences: 1-2=49, 2-3=31, 3-4=52
#
# Group 83: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 84: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 85: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 86: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 87: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 88: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 89: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 90: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 91: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 92: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 93: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 94: [  0  49  80 132]
#   Case: C → Binary: 10
#   Differences: 1-2=49, 2-3=31, 3-4=52
#
# Group 95: [  0  49  80 132]
#   Case: C → Binary: 10
#   Differences: 1-2=49, 2-3=31, 3-4=52
#
# Group 96: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 97: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 98: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 99: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 100: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 101: [  0  49 101 133]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=32
#
# Group 102: [  0  49  80 132]
#   Case: C → Binary: 10
#   Differences: 1-2=49, 2-3=31, 3-4=52
#
# Group 103: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 104: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 105: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 106: [  0  49  81 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=32, 3-4=30
#
# Group 107: [  0  70 101 132]
#   Case: A → Binary: 00
#   Differences: 1-2=70, 2-3=31, 3-4=31
#
# Group 108: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 109: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# Group 110: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 111: [  0  49  80 111]
#   Case: D → Binary: 11
#   Differences: 1-2=49, 2-3=31, 3-4=31
#
# Group 112: [  0  49 101 132]
#   Case: B → Binary: 01
#   Differences: 1-2=49, 2-3=52, 3-4=31
#
# ============================================================
#
# Full Binary String: 01101110011010010111010001100101011110110110011100110000010111110011010001110101011101000011000001101101001101000111010000110011010111110011000001110010010111110110011100110000010111110110100000110000011011010011001101111101
# Binary Length: 224 bits
#
# Decoded ASCII Message: 'nite{g0_4ut0m4t3_0r_g0_h0m3}'
